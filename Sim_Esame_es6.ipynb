# %% [markdown]
# # Simulazione d'esame Laboratorio di Programmazione 2

# %% [markdown]
# ## Esercizio 6
#
# Hai due array NumPy generati come segue:
#
# `x = np.linspace(0, 10, 100)`
# `y = 3 * x + 2 + np.random.normal(0, 1, 100)`
#
# Scrivi una funzione `fit_line(x, y)` che:
#
# - usa `scipy.optimize.curve_fit` per eseguire un **fitting lineare** del tipo `y = a * x + b`;
# - restituisce una tupla contenente:
#   - i **parametri ottimizzati** `a` e `b`;
#   - una **stringa** che descrive la retta trovata, ad esempio: `"y = 3.02 * x + 1.95"`.
#
#
# Esempio di output atteso:   (3.02, 1.95, "y = 3.02 * x + 1.95")
#
# Fai un esempio di utilizzo dove poi plotti i dati e la curva ottenuta.

# %%
import numpy as np
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 100)
y = 3 * x + 2 + np.random.normal(0, 1, 100)

# Funzione modello (retta)
def retta(x, a, b):
    return a * x + b

# Funzione fit_line(x, y)
def fit_line(x, y):
    popt, _ = curve_fit(retta, x, y)
    a, b = popt
    descrizione = f"y = {a:.2f} * x + {b:.2f}"
    return a, b, descrizione

# Utilizzo e output
a, b, descrizione = fit_line(x, y)
print(f"Parametri ottimizzati: a = {a:.2f}, b = {b:.2f}")
print("Descrizione della retta:", descrizione)

# Plot
plt.scatter(x, y, label="Dati originali", alpha=0.5)
plt.plot(x, retta(x, a, b), color='red', label=descrizione)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Fitting lineare con curve_fit")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Parametri ottimizzati: a = 3.03, b = 1.91
# Descrizione della retta: y = 3.03 * x + 1.91
