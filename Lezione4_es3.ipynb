# %% [markdown]
# ## 3. Analisi del Dataset Iris
#
# - Esplora la distribuzione delle specie (conta quanti campioni ci sono per specie)
# - Calcola la lunghezza e la larghezza media dei petali per specie
# - Visualizza le dimensioni dei petali per specie (scatterplot)
# - Crea una nuova colonna per l'area del petalo e analizzala
# - Grafico della distribuzione dell'area del petalo per specie (boxplot)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"
df = pd.read_csv(url)
df.head()

# Esplora la distribuzione delle specie (conteggio per ciascuna)
print("Distribuzione delle specie:")
print(df['species'].value_counts())

# Calcola lunghezza e larghezza media dei petali per specie
print("\nMedia lunghezza e larghezza petalo per specie:")
print(df.groupby('species')[['petal_length', 'petal_width']].mean())

# Visualizza le dimensioni dei petali per specie (scatterplot)
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='petal_length', y='petal_width', hue='species', palette='Set1')
plt.title("Lunghezza vs Larghezza del Petalo per Specie")
plt.xlabel("Lunghezza petalo (cm)")
plt.ylabel("Larghezza petalo (cm)")
plt.grid(True)
plt.show()

# Crea una nuova colonna per l'area del petalo
df['petal_area'] = df['petal_length'] * df['petal_width']

# Analisi dell'area del petalo per specie (boxplot)
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='species', y='petal_area', palette='Set2')
plt.title("Distribuzione dell'Area del Petalo per Specie")
plt.xlabel("Specie")
plt.ylabel("Area petalo (cm²)")
plt.grid(True)
plt.show()
# Out:
# Distribuzione delle specie:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64
#
# Media lunghezza e larghezza petalo per specie:
#             petal_length  petal_width
# species
# setosa             1.462        0.246
# versicolor         4.260        1.326
# virginica          5.552        2.026
# C:\Users\sanic\AppData\Local\Temp\ipykernel_6768\1491779794.py:31: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='species', y='petal_area', palette='Set2')
